# %%
import numpy as np
import tensorflow as tf
import pandas as pd
pd.options.mode.chained_assignment = None
import seaborn as sns
from matplotlib.pylab import rcParams
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import yfinance as yf 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

sns.set(style='whitegrid', palette='muted')
rcParams['figure.figsize'] = 14, 8
np.random.seed(1)
tf.random.set_seed(1)

print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %%
# Getting historical data for Dow Jones Industrial Average index

ticker = 'FB'
sdate = '2016-01-01'
edate = '2020-10-03'

data = yf.download(ticker, sdate, edate)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04  101.949997  102.239998   99.750000  102.220001  102.220001
# 2016-01-05  102.889999  103.709999  101.669998  102.730003  102.730003
# 2016-01-06  101.129997  103.769997  100.900002  102.970001  102.970001
# 2016-01-07  100.500000  101.430000   97.300003   97.919998   97.919998
# 2016-01-08   99.879997  100.500000   97.029999   97.330002   97.330002
#
#               Volume
# Date
# 2016-01-04  37912400
# 2016-01-05  23258200
# 2016-01-06  25096200
# 2016-01-07  45172900
# 2016-01-08  35402300

# %%
data.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f17132e2130>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1713318640>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1713262610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f171320bb80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f17131c3130>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f17131ed6d0>],
#       dtype=object)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = data.index, y = data.Close, mode = 'lines', name = 'Close'))
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <div>                            <div id="0b2f6ae9-22a2-4955-b7bf-a4e1e9f8da1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b2f6ae9-22a2-4955-b7bf-a4e1e9f8da1b")) {                    Plotly.newPlot(                        "0b2f6ae9-22a2-4955-b7bf-a4e1e9f8da1b",                        [{"mode": "lines", "name": "Close", "type": "scatter", "x": ["2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-19T00:00:00", "2016-01-20T00:00:00", "2016-01-21T00:00:00", "2016-01-22T00:00:00", "2016-01-25T00:00:00", "2016-01-26T00:00:00", "2016-01-27T00:00:00", "2016-01-28T00:00:00", "2016-01-29T00:00:00", "2016-02-01T00:00:00", "2016-02-02T00:00:00", "2016-02-03T00:00:00", "2016-02-04T00:00:00", "2016-02-05T00:00:00", "2016-02-08T00:00:00", "2016-02-09T00:00:00", "2016-02-10T00:00:00", "2016-02-11T00:00:00", "2016-02-12T00:00:00", "2016-02-16T00:00:00", "2016-02-17T00:00:00", "2016-02-18T00:00:00", "2016-02-19T00:00:00", "2016-02-22T00:00:00", "2016-02-23T00:00:00", "2016-02-24T00:00:00", "2016-02-25T00:00:00", "2016-02-26T00:00:00", "2016-02-29T00:00:00", "2016-03-01T00:00:00", "2016-03-02T00:00:00", "2016-03-03T00:00:00", "2016-03-04T00:00:00", "2016-03-07T00:00:00", "2016-03-08T00:00:00", "2016-03-09T00:00:00", "2016-03-10T00:00:00", "2016-03-11T00:00:00", "2016-03-14T00:00:00", "2016-03-15T00:00:00", "2016-03-16T00:00:00", "2016-03-17T00:00:00", "2016-03-18T00:00:00", "2016-03-21T00:00:00", "2016-03-22T00:00:00", "2016-03-23T00:00:00", "2016-03-24T00:00:00", "2016-03-28T00:00:00", "2016-03-29T00:00:00", "2016-03-30T00:00:00", "2016-03-31T00:00:00", "2016-04-01T00:00:00", "2016-04-04T00:00:00", "2016-04-05T00:00:00", "2016-04-06T00:00:00", "2016-04-07T00:00:00", "2016-04-08T00:00:00", "2016-04-11T00:00:00", "2016-04-12T00:00:00", "2016-04-13T00:00:00", "2016-04-14T00:00:00", "2016-04-15T00:00:00", "2016-04-18T00:00:00", "2016-04-19T00:00:00", "2016-04-20T00:00:00", "2016-04-21T00:00:00", "2016-04-22T00:00:00", "2016-04-25T00:00:00", "2016-04-26T00:00:00", "2016-04-27T00:00:00", "2016-04-28T00:00:00", "2016-04-29T00:00:00", "2016-05-02T00:00:00", "2016-05-03T00:00:00", "2016-05-04T00:00:00", "2016-05-05T00:00:00", "2016-05-06T00:00:00", "2016-05-09T00:00:00", "2016-05-10T00:00:00", "2016-05-11T00:00:00", "2016-05-12T00:00:00", "2016-05-13T00:00:00", "2016-05-16T00:00:00", "2016-05-17T00:00:00", "2016-05-18T00:00:00", "2016-05-19T00:00:00", "2016-05-20T00:00:00", "2016-05-23T00:00:00", "2016-05-24T00:00:00", "2016-05-25T00:00:00", "2016-05-26T00:00:00", "2016-05-27T00:00:00", "2016-05-31T00:00:00", "2016-06-01T00:00:00", "2016-06-02T00:00:00", "2016-06-03T00:00:00", "2016-06-06T00:00:00", "2016-06-07T00:00:00", "2016-06-08T00:00:00", "2016-06-09T00:00:00", "2016-06-10T00:00:00", "2016-06-13T00:00:00", "2016-06-14T00:00:00", "2016-06-15T00:00:00", "2016-06-16T00:00:00", "2016-06-17T00:00:00", "2016-06-20T00:00:00", "2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-05T00:00:00", "2016-07-06T00:00:00", "2016-07-07T00:00:00", "2016-07-08T00:00:00", "2016-07-11T00:00:00", "2016-07-12T00:00:00", "2016-07-13T00:00:00", "2016-07-14T00:00:00", "2016-07-15T00:00:00", "2016-07-18T00:00:00", "2016-07-19T00:00:00", "2016-07-20T00:00:00", "2016-07-21T00:00:00", "2016-07-22T00:00:00", "2016-07-25T00:00:00", "2016-07-26T00:00:00", "2016-07-27T00:00:00", "2016-07-28T00:00:00", "2016-07-29T00:00:00", "2016-08-01T00:00:00", "2016-08-02T00:00:00", "2016-08-03T00:00:00", "2016 ...

# %%
# Out:
#                  Close
# Date
# 2016-01-04  102.220001
# 2016-01-05  102.730003
# 2016-01-06  102.970001
# 2016-01-07   97.919998
# 2016-01-08   97.330002
# ...                ...
# 2019-10-15  188.889999
# 2019-10-16  189.550003
# 2019-10-17  190.389999
# 2019-10-18  185.850006
# 2019-10-21  189.759995
#
# [957 rows x 1 columns]

# %%
def prep_train_test(data):
    m = data.shape[0]
    train_size = int(m*.8)
    test_size = m - train_size
    return data.iloc[:train_size], data.iloc[train_size:]

# %%
scaler = StandardScaler()
data[["Close_scaled"]] = scaler.fit_transform(data[["Close"]])
train, test  = prep_train_test(data)

# %%
data['Close_scaled'][:10]
# Out:
# Date
# 2016-01-04   -1.678636
# 2016-01-05   -1.665427
# 2016-01-06   -1.659211
# 2016-01-07   -1.790005
# 2016-01-08   -1.805286
# 2016-01-11   -1.800624
# 2016-01-12   -1.752450
# 2016-01-13   -1.854236
# 2016-01-14   -1.778350
# 2016-01-15   -1.866409
# Name: Close_scaled, dtype: float64

# %%
def make_seq(df, col, window = 16):
    x_s , y_s = [], []
    m = df.shape[0]
    for i in range(df.shape[0]-window):
        x_s.append(df[col][i:(i+window)])
        y_s.append([df[col][(i+window)]])
    return np.array(x_s)[:, :, np.newaxis], np.array(y_s)

# %%
x, y = make_seq(data, 'Close_scaled')

# %% [markdown]
# ## Build the AutoEncoder

# %%
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Lambda, Dense, Dropout, TimeDistributed
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping 
# from keras.utils import plot_model

# input_dim = 4
# # timesteps = 3
# latent_dim = 2
# hidden_dim = 4

class Autoencoder():
    def __init__(self, input_dim, time_steps, hidden_dim, latent_dim, dropout = 0.2):
        self.name = 'autoencoder'
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim
        self.dropout = dropout
        self.timesteps = time_steps


    def build(self):
#       costum RepeatVector for variable lenght sequnces
#       def repeat(x):

#         stepMatrix = K.ones_like(x[0][:,:,:1]) #matrix with ones, shaped as (batch, steps, 1)
#         latentMatrix = K.expand_dims(x[1],axis=1) #latent vars, shaped as (batch, 1, latent_dim)

#         return K.batch_dot(stepMatrix,latentMatrix)

        inputs = Input(shape=(None, input_dim), name = "input_layer")
        encoded_l1 = LSTM(hidden_dim, return_sequences=True, name = "elstm_I")(inputs)
        encoded_l2 = LSTM(latent_dim, name = "elstm_out")(encoded_l1)
        encoded_l3 = Dropout(self.dropout)(encoded_l2)
#       for variable lenght sequnces
#       decoded_rep = Lambda(repeat, name = 'lambda')([inputs,encoded_l2])
        decoded_rep = RepeatVector(self.timesteps)(encoded_l3)
        decoded_l1 = LSTM(input_dim, return_sequences=True, name = 'dlstm_I')(decoded_rep)
        decoded_l2 = Dropout(self.dropout)(decoded_l1)
        decoded_l3 = LSTM(hidden_dim, return_sequences = True, name = 'dlstm_out')(decoded_l2)
        decoded_out = TimeDistributed(Dense(self.input_dim))(decoded_l3)
        #full Autoencoder
        self.autoencoder_model = Model(inputs, decoded_out, name = 'AE')
        #the encoder
        
        self.encoder_model = Model(inputs, encoded_l3, name = "encoder")
    def compile(self, learning_rate = 0.001 ):
        self.learning_rate = learning_rate
        optimizer = Adam(lr = learning_rate)
        self.autoencoder_model.compile(optimizer = optimizer, loss = 'mae')

# %%
del Autoencoder

# %%
input_dim = x.shape[2]
time_steps = x.shape[1]
latent_dim = 64
hidden_dim = 128
AE = Autoencoder(input_dim, time_steps, hidden_dim, latent_dim)

# %%
AE.build()

# %%
AE.autoencoder_model.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, None, 1)]         0
# _________________________________________________________________
# elstm_I (LSTM)               (None, None, 128)         66560
# _________________________________________________________________
# elstm_out (LSTM)             (None, 64)                49408
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# repeat_vector_11 (RepeatVect (None, 16, 64)            0
# _________________________________________________________________
# dlstm_I (LSTM)               (None, 16, 1)             264
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 16, 1)             0
# _________________________________________________________________
# dlstm_out (LSTM)             (None, 16, 128)           66560
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 16, 1)             129
# =================================================================
# Total params: 182,921
# Trainable params: 182,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.compile()

# %%
es = EarlyStopping(monitor = 'val_loss', patience = 3 , mode = 'min')
history = AE.autoencoder_model.fit(x, y, epochs = 3)
# Out:
# Epoch 1/3
# 37/37 [==============================] - 2s 57ms/step - loss: 0.4978
# Epoch 2/3
# 37/37 [==============================] - 2s 57ms/step - loss: 0.3122
# Epoch 3/3
# 37/37 [==============================] - 2s 59ms/step - loss: 0.2734
